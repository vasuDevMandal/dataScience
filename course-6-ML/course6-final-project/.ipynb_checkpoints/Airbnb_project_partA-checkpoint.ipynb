# %%
# video link
# https://drive.google.com/file/d/12St9wU0JN9i1V5nVp_2W2mktDGLz6aST/view?usp=sharing

import pandas as pd
from sklearn.ensemble import RandomForestRegressor
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import seaborn as sns
import ast


# Loading  dataset
df = pd.read_csv('Airbnb_data - airbnb_data.csv')

# checking data and tables
print(df.shape)
print(df.columns)
df.head()
# Out:
# (74111, 29)
# Index(['id', 'log_price', 'property_type', 'room_type', 'amenities',
#        'accommodates', 'bathrooms', 'bed_type', 'cancellation_policy',
#        'cleaning_fee', 'city', 'description', 'first_review',
#        'host_has_profile_pic', 'host_identity_verified', 'host_response_rate',
#        'host_since', 'instant_bookable', 'last_review', 'latitude',
#        'longitude', 'name', 'neighbourhood', 'number_of_reviews',
#        'review_scores_rating', 'thumbnail_url', 'zipcode', 'bedrooms', 'beds'],
#       dtype='object')
#          id  log_price property_type        room_type  \
# 0   6901257   5.010635     Apartment  Entire home/apt
# 1   6304928   5.129899     Apartment  Entire home/apt
# 2   7919400   4.976734     Apartment  Entire home/apt
# 3  13418779   6.620073         House  Entire home/apt
# 4   3808709   4.744932     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...             7        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.0
# 4  {TV,Internet,"Wireless Internet","Air conditio...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee  ...   latitude   longitude  \
# 0  Real Bed              strict          True  ...  40.696524  -73.991617
# 1  Real Bed              strict          True  ...  40.766115  -73.989040
# 2  Real Bed            moderate          True  ...  40.808110  -73.943756
# 3  Real Bed            flexible          True  ...  37.772004 -122.431619
# 4  Real Bed            moderate          True  ...  38.925627  -77.034596
#
#                                        name     neighbourhood  \
# 0            Beautiful brownstone 1-bedroom  Brooklyn Heights
# 1  Superb 3BR Apt Located Near Times Square    Hell's Kitchen
# 2                          The Garden Oasis            Harlem
# 3        Beautiful Flat in the Heart of SF!      Lower Haight
# 4                Great studio in midtown DC  Columbia Heights
#
#   number_of_reviews review_scores_rating  \
# 0                 2                100.0
# 1                 6                 93.0
# 2                10                 92.0
# 3                 0                  NaN
# 4                 4                 40.0
#
#                                        thumbnail_url zipcode bedrooms  beds
# 0  https://a0.muscache.com/im/pictures/6d7cbbf7-c...   11201      1.0   1.0
# 1  https://a0.muscache.com/im/pictures/348a55fe-4...   10019      3.0   3.0
# 2  https://a0.muscache.com/im/pictures/6fae5362-9...   10027      1.0   3.0
# 3  https://a0.muscache.com/im/pictures/72208dad-9...   94117      2.0   2.0
# 4                                                NaN   20009      0.0   1.0
#
# [5 rows x 29 columns]

# %%
#Summary of numerical features
df.describe()
txt = 'total records : {}'.format(df.shape[0])
print(txt)
# Checking missing values
missing = df.isnull().sum().sort_values(ascending=False)
missing[missing > 0]
# Out:
# total records : 74111
# host_response_rate        18299
# review_scores_rating      16722
# first_review              15864
# last_review               15827
# thumbnail_url              8216
# neighbourhood              6872
# zipcode                     968
# bathrooms                   200
# host_identity_verified      188
# host_since                  188
# host_has_profile_pic        188
# beds                        131
# bedrooms                     91
# dtype: int64

# %%
# Filling missing review scores with mean (or median)
df['host_response_rate'].fillna(0, inplace=True)
df['review_scores_rating'].fillna(df['review_scores_rating'].mean(), inplace=True)
df['first_review'].fillna('05-10-2017', inplace=True)
df['last_review'].fillna('05-10-2017', inplace=True)
df['thumbnail_url'].fillna('NA', inplace=True)
df['neighbourhood'].fillna('NA', inplace=True)
df['zipcode'].fillna(0, inplace=True)
df['bathrooms'].fillna(0, inplace=True)
df['host_identity_verified'].fillna(False, inplace=True)
df['host_since'].fillna('05-10-2017', inplace=True)
df['host_has_profile_pic'].fillna(False, inplace=True)
df['beds'].fillna(0, inplace=True)
df['bedrooms'].fillna(0, inplace=True)

# Converting date columns to datetime
df['first_review'] = pd.to_datetime(df['first_review'], errors='coerce', dayfirst=True)
df['last_review'] = pd.to_datetime(df['last_review'], errors='coerce', dayfirst=True)
df['host_since'] = pd.to_datetime(df['host_since'], errors='coerce', dayfirst=True)
# Out:
# C:\Users\vdm\AppData\Local\Temp\ipykernel_5960\276796994.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['host_response_rate'].fillna(0, inplace=True)
# C:\Users\vdm\AppData\Local\Temp\ipykernel_5960\276796994.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['review_scores_rating'].fillna(df['review_scores_rating'].mean(), inplace=True)
# C:\Users\vdm\AppData\Local\Temp\ipykernel_5960\276796994.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['first_review'].fillna('05-10-2017', inplace=True)
# C:\Users\vdm\AppData\Local\Temp\ipykernel_5960\276796994.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['last_review'].fillna('05-10-2017', inplace=True)
# C:\Users\vdm\AppData\Local\Temp\ipykernel_5960\276796994.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['thumbnail_url'].fillna('NA', inplace=True)
# C:\Users\vdm\AppData\Local\Temp\ipykernel_5960\276796994.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['neighbourhood'].fillna('NA', inplace=True)
# C:\Users\vdm\AppData\Local\Temp\ipykernel_5960\276796994.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['zipcode'].fillna(0, inplace=True)
# C:\Users\vdm\AppData\Local\Temp\ipykernel_5960\276796994.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bathrooms'].fillna(0, inplace=True)
# C:\Users\vdm\AppData\Local\Temp\ipykernel_5960\276796994.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['host_identity_verified'].fillna(False, inplace=True)
# C:\Users\vdm\AppData\Local\Temp\ipykernel_5960\276796994.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['host_since'].fillna('05-10-2017', inplace=True)
# C:\Users\vdm\AppData\Local\Temp\ipykernel_5960\276796994.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['host_has_profile_pic'].fillna(False, inplace=True)
# C:\Users\vdm\AppData\Local\Temp\ipykernel_5960\276796994.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['beds'].fillna(0, inplace=True)
# C:\Users\vdm\AppData\Local\Temp\ipykernel_5960\276796994.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bedrooms'].fillna(0, inplace=True)

# %%
# Check all values
df.describe()
txt = 'total records : {}'.format(df.shape[0])
print(txt)

# Checking missing values
missing2 = df.isnull().sum().sort_values(ascending=False)
missing2[missing2 > 0]
# Out:
# total records : 74111
# Series([], dtype: int64)

# %%
# Drop rows with extremely high prices

# remove listings priced above 1000
# df = df[np.exp(df['log_price']) < 1000]  

df['price'] = np.exp(df['log_price'])

# %%
def countAmenities(amenStr):
    try:
        amenitiesList = ast.literal_eval(amenStr)
        return len(amenitiesList)
    except:
        return 0

df['num_amenities'] = df['amenities'].apply(countAmenities)

# %%
df['host_experience_days'] = (pd.to_datetime('today') - df['host_since']).dt.days
df['host_experience_days'].fillna(df['host_experience_days'].median())
# Out:
# 0        4790
# 1        2879
# 2        3116
# 3        3671
# 4        3720
#          ...
# 74106    4427
# 74107    3291
# 74108    4871
# 74109    2789
# 74110    4545
# Name: host_experience_days, Length: 74111, dtype: int64

# %%
df['days_since_last_review'] = (pd.to_datetime('today') - df['last_review']).dt.days
df['days_since_last_review'].fillna(df['days_since_last_review'].median())
# Out:
# 0        3215
# 1        2783
# 2        2792
# 3        2771
# 4        3027
#          ...
# 74106    2771
# 74107    2944
# 74108    2796
# 74109    2771
# 74110    2929
# Name: days_since_last_review, Length: 74111, dtype: int64

# %%
categorical_cols = ['property_type', 'room_type', 'bed_type', 'cancellation_policy', 'city']
df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# %%
drop_cols = ['id', 'log_price', 'description', 'name', 'thumbnail_url', 'amenities',
             'host_response_rate', 'zipcode', 'host_has_profile_pic', 'host_identity_verified']
df.drop(columns=drop_cols, inplace=True)

# %%
# checking values in error causing object columns
print(df['instant_bookable'].unique())
print(df['neighbourhood'].unique())


# mapping data to correct input type
df['instant_bookable'] = df['instant_bookable'].map({'t': True, 'f': False})
df['neighbourhood'] = df['neighbourhood'].replace('NA', np.nan)


# From large list of neighbourhood, keeping only large neighbourhood
topNeighbourhood = df['neighbourhood'].value_counts().nlargest(20).index
df['neighbourhood'] = df['neighbourhood'].apply(lambda x: x if x in topNeighbourhood else 'Other')

df = pd.get_dummies(df, columns=['neighbourhood'], drop_first=True)


# removing outliers for better results
df = df[df['price'] < df['price'].quantile(0.99)]

df['host_days_active'] = (df['last_review'] - df['host_since']).dt.days.clip(lower=0)
df['listing_age'] = (df['last_review'] - df['first_review']).dt.days.clip(lower=0)
df.drop(columns=['first_review', 'last_review', 'host_since'], inplace=True)
# Out:
# ['f' 't']
# ['Brooklyn Heights' "Hell's Kitchen" 'Harlem' 'Lower Haight'
#  'Columbia Heights' 'Noe Valley' 'NA' 'Downtown' 'Richmond District'
#  'Alphabet City' 'Hermosa Beach' 'Torrance' 'U Street Corridor'
#  'Humboldt Park' 'Wicker Park' 'South Boston' 'Lower East Side' 'Flatbush'
#  'Sherman Oaks' 'East Flatbush' 'Valley Glen' 'Dupont Circle' 'Jamaica'
#  'Forest Hills' 'Murray Hill' 'Lefferts Garden' 'Mid-Wilshire' 'Venice'
#  'West Hollywood' 'Brownsville' 'Williamsburg' 'East Village'
#  'South Loop/Printers Row' 'Westlake' 'Hollywood Hills' 'Upper East Side'
#  'Bushwick' 'Bedford-Stuyvesant' 'Pilsen' 'Chelsea' 'Sunnyside'
#  'Greenwich Village' 'Washington Heights' 'Pasadena' 'Potrero Hill'
#  'Brookland' 'Los Feliz' 'Hollywood' 'Midtown East' 'Glendale'
#  'Park Slope' 'Arcadia' 'West Village' 'Astoria' 'Portola' 'Burbank'
#  'East Harlem' 'Silver Lake' 'Hillbrook' 'Shaw' 'Hillcrest'
#  'Morningside Heights' 'Tribeca' 'Studio City' 'Western Addition/NOPA'
#  'Echo Park' 'Financial District' 'Lakeview' 'Gramercy Park'
#  'Mission District' 'Kingman Park' 'Sunset Park' 'Upper West Side'
#  'Greenpoint' 'Highland Park' 'Cleveland Park' 'Prospect Heights'
#  'Glover Park' 'Gravesend' 'Jamaica Plain' 'Beacon Hill' 'SoMa' 'Flushing'
#  'Van Nuys' 'Del Rey' 'Midtown' 'Soho' 'Mission Hill' 'Roosevelt Island'
#  'Marina Del Rey' 'West Roxbury' 'Streeterville' 'Bernal Heights'
#  'Soundview' 'North Beach' 'Belmont Cragin' 'Crown Heights' 'Gowanus'
#  'Boerum Hill' 'Greenwood Heights' 'Chinatown' 'Charlestown' 'Alhambra'
#  'South End' 'Windsor Terrace' 'Sheepshead Bay' 'Westwood' 'Malibu'
#  'Allston-Brighton' 'Clinton Hill' 'The Castro' 'Alamo Square'
#  'Westerleigh' 'Georgetown' 'North Hollywood' 'Twin Peaks' 'Pacoima'
#  'Roxbury' 'Ridgewood' 'Battery Park City' 'Park View' 'Lomita' 'Mid-City'
#  'Sun Valley' 'Haight-Ashbury' 'River North' 'Cahuenga Pass' 'Cerritos'
#  'Arts District' 'Valley Village' 'West Adams' 'North End' 'The Rockaways'
#  'Santa Monica' 'Downtown Brooklyn' 'Midwood' 'Inglewood' 'Capitol Hill'
#  'Beverly Hills' 'Fenway/Kenmore' 'Foggy Bottom' 'East Hollywood'
#  'Gardena' 'Mount Pleasant' 'Gold Coast' 'Mission Terrace'
#  'Near Northeast/H Street Corridor' 'Northridge' 'Woodridge' 'Petworth'
#  'Toluca Lake' 'San Pedro' 'Colonial Village' 'Nob Hill' 'Edgewater'
#  'LeDroit Park' 'Fort Greene' 'Flatiron District' 'Lake Balboa'
#  'Bay Ridge' 'Telegraph Hill' 'West End' 'Bloomingdale' 'Judiciary Square'
#  'Downtown Crossing' 'Pacific Palisades' 'West Town/Noble Square'
#  'Glendora' 'Mount Washington' 'Cole Valley' 'Uptown' 'Russian Hill'
#  'Manor Park' 'Inwood' 'Benning Heights' 'Visitacion Valley'
#  'Ukrainian Village' 'Kips Bay' 'Eastchester' '16th Street Heights'
#  'Long Island City' 'Hamilton Heights' 'Carroll Gardens'
#  'Bel Air/Beverly Crest' 'Hayes Valley' 'Rego Park' 'Lincoln Park'
#  'Bayside' 'Dorchester' 'Hawthorne' 'West Loop/Greektown' 'Redondo Beach'
#  'Culver City' 'Portage Park' 'Bayview' 'Barney Circle' 'Back Bay'
#  'North Hills West' 'Mott Haven' 'Michigan Park'
#  'Westchester/Playa Del Rey' 'Pacific Heights' 'Monterey Hills'
#  'Jackson Heights' 'Long Beach' 'Manhattan Beach' 'Fort Totten'
#  'Hudson Square' 'Laurel Canyon' 'Marine Park' 'Parkside' 'Trinidad'
#  'Lincoln Square' 'Little Italy' 'Chevy Chase' 'Crocker Amazon'
#  'Inner Sunset' 'Fort Wadsworth' 'Bensonhurst' 'Anacostia' 'South LA'
#  'Winthrop' 'Altadena' 'West Los Angeles' 'South Street Seaport'
#  'Union Square' 'Duboce Triangle' 'Hyde Park' 'East New York'
#  'Adams Morgan' 'Castleton Corners' 'Wakefield' 'Azusa' 'Logan Circle'
#  'Mar Vista' 'Fort Dupont' 'Ozone Park' 'Stronghold' 'South Robertson'
#  'Noho' 'Old Town' 'Ingleside' 'Canarsie' 'Kalorama'
#  'Downtown/Penn Quarter' 'Topanga' 'Columbia Street Waterfront' 'Maspeth'
#  'Boystown' 'Fordham' 'Southwest Waterfront' 'West Ridge' 'St. George'
#  'Bellevue' 'Stapleton' 'Lawndale' 'Encino' 'Brooklyn Navy Yard' 'Nolita'
#  'Civic Center' 'Truxton Circle' 'University Heights'
#  'Times Square/Theatre District' 'Avondale' 'Kensington'
#  'East San Gabriel' 'Eagle Rock' 'Ditmars / Steinway' 'Fairlawn'
#  'Irving Park' 'Mount Eden' 'South Beach' 'Flatlands' 'Lincoln Heights'
#  'Bronzeville' 'Bradbury' 'San Gabriel' 'Red Hook' 'Claremont' 'Austin'
#  'Carson' 'East Boston' 'Brighton Beach' 'Woodhaven' 'Cow Hollow'
#  'Logan Square' 'Hunts Point' 'Baldwin Hills' 'Bucktown'
#  'Kew Garden Hills' 'Highbridge' 'Meatpacking District' 'South Ozone Park'
#  'Loop' 'Middle Village' 'Navy Yard' 'Brentwood'
#  'Woodland Hills/Warner Center' 'Outer Sunset' 'Rosebank' 'Riverdale'
#  'Oakwood' 'Glassell Park' 'Mount Vernon Square' 'Granada Hills North'
#  'Bridgeport' 'Marina' 'West Brighton' 'Queens' 'Little Italy/UIC'
#  'Westside' 'Rancho Palos Verdes' 'Woodside' 'Fort Lincoln' 'Tenderloin'
#  'Japantown' 'Norwood Park' 'Elysian Valley' 'Dogpatch' 'Excelsior'
#  'Concord' 'Rosemead' 'Reseda' 'West Hills' 'East Elmhurst' 'Eckington'
#  'Concourse' 'Palms' 'Andersonville' 'Rogers Park' 'River Terrace'
#  'Dyker Heights' 'Theater District' 'Throgs Neck' 'South Pasadena'
#  'Sunland/Tujunga' 'Richmond Hill' 'El Segundo' 'Skid Row' 'Tremont'
#  'Forest Hill' 'Porter Ranch' 'Bergen Beach' 'Monterey Park' 'Lakewood'
#  'Diamond Heights' 'Englewood' 'Chatsworth' 'Roslindale' 'Atwater Village'
#  'Compton' 'Elmhurst' 'Lakeshore' 'Chestnut Hill' 'Kingsbridge Heights'
#  'Oceanview' 'North Michigan Park' 'Van Nest' 'Near West Side' 'Tarzana'
#  'City Island' 'Coney Island' 'Somerville' 'Congress Heights'
#  'Woodley Park' 'Winnetka' 'Grand Crossing' 'Roscoe Village'
#  'Garfield Park' 'River West' 'Central Northeast/Mahaning Heights'
#  'Kingsbridge' 'Marble Hill' 'Crestwood' 'Daly City' 'Dunning' 'Corona'
#  'Emerson Hill' 'Edgewood' 'Morris Heights' 'Mattapan' 'Ivy City'
#  'Palisades' 'Mt Rainier/Brentwood, MD' 'Temple City' 'Baychester'
#  'Presidio Heights' 'Pico Rivera' 'El Monte' 'Hermon' 'Glen Park'
#  'East Corner' 'Parkchester' 'Whitestone' 'Cobble Hill' 'Takoma'
#  'Near North Side' 'South Shore' 'Bedford Park' 'Vernon' 'Pelham Bay'
#  'Benning Ridge' 'Manhattan' 'Concourse Village' 'La Canada Flintridge'
#  'Lamond Riggs' 'Utopia' 'Foxhall' 'Longwood' 'Howard Beach' 'West Covina'
#  'Woodlawn' 'Mission Bay' 'Balboa Terrace' 'Vinegar Hill' 'Langdon'
#  'North Center' 'Covina' 'Morrisania' 'College Point' 'Douglass'
#  'Monrovia' 'McKinley Park' 'Observatory Circle' 'West Athens' 'Cambridge'
#  'Government Center' 'East Los Angeles' 'Gateway' 'Leather District'
#  'Fresh Meadows' 'Crotona' 'Carver Langston' 'Pleasant Plains'
#  'Marshall Heights' 'Sierra Madre' "Fisherman's Wharf" 'Whittier'
#  'Little Village' 'West Puente Valley' 'Benning' 'Randle Highlands' 'Kent'
#  'Lynwood' 'Tompkinsville' 'La Puente' 'La Mirada' 'Chatham' 'El Sereno'
#  'Borough Park' 'Kenwood' 'American University Park' 'Printers Row'
#  'Boyle Heights' 'Jefferson Park' 'Brightwood' 'Palos Verdes'
#  'Park Versailles' 'Skyland' 'Midland Beach' 'West Lawn'
#  'La Crescenta-Montrose' 'Williamsbridge' 'Harbor City'
#  'Cathedral Heights' 'Berkley' 'Eltingville' 'Pleasant Hill'
#  'Panorama City' 'Cypress Park' 'West Town' 'North Lawndale'
#  'Wrigleyville' 'Good Hope' 'Bethesda, MD' 'Meiers Corners'
#  'Rolling Hills Estates' 'Mt. Vernon Square' 'Brooklyn' 'Archer Heights'
#  'Friendship Heights' 'DUMBO' 'Brookline' 'Harbor Gateway' 'Sea Cliff'
#  'Bellflower' 'Wesley Heights' 'Westmont' 'West Elsdon'
#  'Back of the Yards' 'Bronxdale' 'Hilcrest Heights/Marlow Heights, MD'
#  'Twining' 'Florence-Graham' 'West Portal' 'The Bronx' 'Grasmere'
#  'Melrose' 'Pullman' 'Hermosa' 'Canoga Park' 'North Hills East'
#  'South San Gabriel' 'Allerton' 'Norwood' 'Sea Gate' 'Sylmar' 'Belmont'
#  'Grymes Hill' 'Albany Park' 'Arleta' 'San Marino' 'Morris Park'
#  'North Cleveland Park' 'Washington Park' 'Duarte' 'Oakland' 'Clearing'
#  'South Gate' 'Co-op City' 'Shepherd Park' 'New Brighton' 'Bell'
#  'Edenwald' 'Burleith' 'Norwalk' 'North Park' 'Annadale'
#  'Montecito Heights' 'Huntington Park' 'Hawaiian Gardens' 'Auburn Gresham'
#  'Westchester Village' "O'Hare" 'Gallaudet' 'Mt. Pleasant'
#  'South Whittier' 'Downey' 'Elm Park' 'Spuyten Duyvil' 'Santa Fe Springs'
#  'Massachusetts Heights' 'Coolidge Corner' 'Todt Hill' 'Buena Vista'
#  'Galewood' 'Mariners Harbor' 'West Farms' 'Deanwood' 'Armour Square'
#  'Port Morris' 'Suitland-Silver Hill, MD' 'Dupont Park' 'Brighton Park'
#  'Montebello' 'Morgan Park' 'Chevy Chase, MD' 'Garfield Heights'
#  'Castle Hill' "Old Soldiers' Home" 'New Springville' 'Port Richmond'
#  'Eastland Gardens' 'Shipley Terrace' 'Artesia' 'Randall Manor'
#  'Paramount' 'Greenway' 'Baldwin Park' 'Bath Beach' 'Mission Hills'
#  'St. Elizabeths' 'Washington Highlands' 'Dongan Hills' 'Chillum, MD'
#  'Alondra Park' 'Huguenot' 'Fort Davis' 'Watts' 'Signal Hill'
#  'Great Kills' 'Willowbrook' 'Roseland' 'Arrochar' 'Edison Park'
#  'Silver Spring, MD' 'Mill Basin' 'South Chicago' 'Graniteville'
#  'Garfield Ridge' 'Spring Valley' 'Tottenville' 'Presidio' 'Lindenwood'
#  'Naylor Gardens' 'Clifton' 'Ashburn' 'Beverly' 'Barry Farm' 'Wilmington'
#  'Country Club' 'Lighthouse HIll' 'Magnificent Mile' 'Arboretum'
#  'Woodland' 'New Dorp Beach' 'Takoma Park, MD' 'Near Northeast'
#  'Harvard Square' 'Commerce' 'South El Monte' 'Montclare' 'Newton'
#  'Watertown' 'Gerritsen Beach' 'Rossville' 'La Habra' 'Irwindale'
#  'Rolling Hills' 'Grant City']

# %%
X = df.drop(columns=['price'])

# trying to curb outliers affects in price 
y = df['price']
# y = np.log1p(df['price']) 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# dropping datetime columns as it can not handle this as they expect numerical values only
X_train = X_train.drop(columns=X_train.select_dtypes(include=['datetime']).columns)
X_test = X_test.drop(columns=X_test.select_dtypes(include=['datetime']).columns)

# %%
# print(X_train.dtypes)
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73369 entries, 0 to 74110
# Data columns (total 85 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   accommodates                         73369 non-null  int64
#  1   bathrooms                            73369 non-null  float64
#  2   cleaning_fee                         73369 non-null  bool
#  3   instant_bookable                     73369 non-null  bool
#  4   latitude                             73369 non-null  float64
#  5   longitude                            73369 non-null  float64
#  6   number_of_reviews                    73369 non-null  int64
#  7   review_scores_rating                 73369 non-null  float64
#  8   bedrooms                             73369 non-null  float64
#  9   beds                                 73369 non-null  float64
#  10  price                                73369 non-null  float64
#  11  num_amenities                        73369 non-null  int64
#  12  host_experience_days                 73369 non-null  int64
#  13  days_since_last_review               73369 non-null  int64
#  14  property_type_Bed & Breakfast        73369 non-null  bool
#  15  property_type_Boat                   73369 non-null  bool
#  16  property_type_Boutique hotel         73369 non-null  bool
#  17  property_type_Bungalow               73369 non-null  bool
#  18  property_type_Cabin                  73369 non-null  bool
#  19  property_type_Camper/RV              73369 non-null  bool
#  20  property_type_Casa particular        73369 non-null  bool
#  21  property_type_Castle                 73369 non-null  bool
#  22  property_type_Cave                   73369 non-null  bool
#  23  property_type_Chalet                 73369 non-null  bool
#  24  property_type_Condominium            73369 non-null  bool
#  25  property_type_Dorm                   73369 non-null  bool
#  26  property_type_Earth House            73369 non-null  bool
#  27  property_type_Guest suite            73369 non-null  bool
#  28  property_type_Guesthouse             73369 non-null  bool
#  29  property_type_Hostel                 73369 non-null  bool
#  30  property_type_House                  73369 non-null  bool
#  31  property_type_Hut                    73369 non-null  bool
#  32  property_type_In-law                 73369 non-null  bool
#  33  property_type_Island                 73369 non-null  bool
#  34  property_type_Lighthouse             73369 non-null  bool
#  35  property_type_Loft                   73369 non-null  bool
#  36  property_type_Other                  73369 non-null  bool
#  37  property_type_Parking Space          73369 non-null  bool
#  38  property_type_Serviced apartment     73369 non-null  bool
#  39  property_type_Tent                   73369 non-null  bool
#  40  property_type_Timeshare              73369 non-null  bool
#  41  property_type_Tipi                   73369 non-null  bool
#  42  property_type_Townhouse              73369 non-null  bool
#  43  property_type_Train                  73369 non-null  bool
#  44  property_type_Treehouse              73369 non-null  bool
#  45  property_type_Vacation home          73369 non-null  bool
#  46  property_type_Villa                  73369 non-null  bool
#  47  property_type_Yurt                   73369 non-null  bool
#  48  room_type_Private room               73369 non-null  bool
#  49  room_type_Shared room                73369 non-null  bool
#  50  bed_type_Couch                       73369 non-null  bool
#  51  bed_type_Futon                       73369 non-null  bool
#  52  bed_type_Pull-out Sofa               73369 non-null  bool
#  53  bed_type_Real Bed                    73369 non-null  bool
#  54  cancellation_policy_moderate         73369 non-null  bool
#  55  cancellation_policy_strict           73369 non-null  bool
#  56  cancellation_policy_super_strict_30  73369 non-null  bool
#  57  cancellation_policy_super_strict_60  73369 non-null  bool
#  58  city_Chicago                         73369 non-null  bool
#  59  city_DC                              73369 non-null  bool
#  60  city_LA                              73369 non-null  bool
#  61  city_NYC                             73369 non-null  bool
#  62  city_SF                              73369 non-null  bool
#  63  neighbourhood_Bedford-Stuyvesant     73369 non-null  bool
#  64  neighbourhood_Bushwick               73369 non-null  bool
#  65  neighbourhood_Chelsea                73369 non-null  bool
#  66  neighbourhood_Crown Heights          73369 non-null  bool
#  67  neighbourhood_East Harlem            73369 non-null  bool
#  68  neighbourhood_East Village           73369 non-null  bool
#  69  neighbourhood_Greenpoint             73369 non-null  bool
#  70  neighbourhood_Harlem                 73369 non-null  bool
#  71  neighbourhood_Hell's Kitchen         73369 non-null  bool
#  72  neighbourhood_Hollywood              73369 non-null  bool
#  73  neighbourhood_Lower East Side        73369 non-null  bool
#  74  neighbourhood_Mid-Wilshire           73369 non-null  bool
#  75  neighbourhood_Mission District       73369 non-null  bool
#  76  neighbourhood_Other                  73369 non-null  bool
#  77  neighbourhood_Upper East Side        73369 non-null  bool
#  78  neighbourhood_Upper West Side        73369 non-null  bool
#  79  neighbourhood_Venice                 73369 non-null  bool
#  80  neighbourhood_Washington Heights     73369 non-null  bool
#  81  neighbourhood_West Hollywood         73369 non-null  bool
#  82  neighbourhood_Williamsburg           73369 non-null  bool
#  83  host_days_active                     73369 non-null  int64
#  84  listing_age                          73369 non-null  int64
# dtypes: bool(71), float64(7), int64(7)
# memory usage: 13.4 MB

# %%
# checking for non numeric types in X, so we can remove objects and other types which model won't handle, empty is target
non_numeric_columns = X_train.select_dtypes(include=['object']).columns
print("Non-numeric columns:", non_numeric_columns)
# Out:
# Non-numeric columns: Index([], dtype='object')

# %%
def evaluateModel(model, X_test, y_test):
    pred = model.predict(X_test)
    
    rmse = np.sqrt(mean_squared_error(y_test, pred))
    
    mae = mean_absolute_error(y_test, pred)
    
    r2 = r2_score(y_test, pred)

    print(f"RMSE: {rmse:.2f}")
    print(f"MAE: {mae:.2f}")
    print(f"R²: {r2:.4f}")
    
    return pred

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

print("Linear Regression Results:")
lr_preds = evaluateModel(lr, X_test, y_test)
# Out:
# Linear Regression Results:
# RMSE: 89.76
# MAE: 55.67
# R²: 0.4847

# %%
# rf = RandomForestRegressor(n_estimators=100, random_state=42)
# rf.fit(X_train, y_train)

# print("Random Forest Results:")
# rf_preds = evaluate_model(rf, X_test, y_test)


# new approach for better results - removing low importance features for better accuracy in predictions


# training model first
rf = RandomForestRegressor(n_estimators=100, random_state=51)
rf.fit(X_train, y_train)

# Get all feature of importances
importances = pd.Series(rf.feature_importances_, index=X_train.columns)

#Filter important features, drop lower importance features
threshold = 0.005
importantFeatures = importances[importances > threshold].index.tolist()
print(f"Keeping {len(importantFeatures)} out of {len(importances)} features")

# new reduced feature set
X_train_r = X_train[importantFeatures]
X_test_r = X_test[importantFeatures]

# retraining on reduced feature set
rf_reduced = RandomForestRegressor(n_estimators=100, random_state=51)
rf_reduced.fit(X_train_r, y_train)

# evaluating reduced features randomForest
print("Random Forest Results - With Reduced Features:")
rf_preds = evaluateModel(rf_reduced, X_test_r, y_test)
# Out:
# Keeping 19 out of 84 features
# Random Forest Results - With Reduced Features:
# RMSE: 81.23
# MAE: 46.48
# R²: 0.5780

# %%
importances = pd.Series(rf.feature_importances_, index=X_train.columns)
topFeatures = importances.sort_values(ascending=False).head(20)

plt.figure(figsize=(10, 6))
sns.barplot(x=topFeatures.values, y=topFeatures.index)
plt.title("Top 20 Feature Importances (Random Forest)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 4
#       1 importances = pd.Series(rf.feature_importances_, index=X_train.columns)
#       2 topFeatures = importances.sort_values(ascending=False).head(20)
# ----> 4 plt.figure(figsize=(10, 6))
#       5 sns.barplot(x=topFeatures.values, y=topFeatures.index)
#       6 plt.title("Top 20 Feature Importances (Random Forest)")
#
# NameError: name 'plt' is not defined

# %%
results = {
    "Model": ["Linear Regression", "Random Forest"],
    "RMSE": [
        np.sqrt(mean_squared_error(y_test, lr_preds)),
        np.sqrt(mean_squared_error(y_test, rf_preds))
    ],
    "MAE": [
        mean_absolute_error(y_test, lr_preds),
        mean_absolute_error(y_test, rf_preds)
    ],
    "R²": [
        r2_score(y_test, lr_preds),
        r2_score(y_test, rf_preds)
    ]
}

pd.DataFrame(results)

# %%
#Setting up the data
metrics_df = pd.DataFrame(results)

# using Melt,for easier plotting
metrics_melted = metrics_df.melt(id_vars="Model", var_name="Metric", value_name="Value")

# graph
plt.figure(figsize=(10, 6))
sns.barplot(data=metrics_melted, x="Metric", y="Value", hue="Model")

plt.title("Model Comparison for Evaluation Metrics")
plt.ylabel("score")

plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Linear-Regression - fig-axis-0
axs[0].scatter(y_test, lr_preds, alpha=0.3, color='blue')
axs[0].plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')

axs[0].set_title("Linear Regression- Actual vs Predicted")
axs[0].set_xlabel("Actual Price")
axs[0].set_ylabel("Predicted Price")

# Random-Forest - fig-axis-1
axs[1].scatter(y_test, rf_preds, alpha=0.3, color='green')
axs[1].plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')

axs[1].set_title("Random Forest- Actual vs Predicted")
axs[1].set_xlabel("Actual Price")
axs[1].set_ylabel("Predicted Price")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['price'], bins=50, kde=True)
plt.title("Airbnb Prices Distribution")
plt.xlabel("Price")
plt.ylabel("Number of Listings")
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x='instant_bookable', y='price', data=df)


plt.title("Price vs Instant Bookable")
plt.xlabel("Instant Bookable")

plt.ylabel("Price")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x='bedrooms', y='price', data=df)

plt.title("Price Distribution by bedrooms")
plt.xlabel("bedrooms")
plt.ylabel("Price")

plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='accommodates', y='price', data=df)

plt.title("Price Distribution by accommodations")
plt.xlabel("accommodates")
plt.ylabel("Price")

plt.show()

# %%
# For predicting new listings

new_listing_parameters = {
    'bedrooms': 4,
    'beds': 4,
    'bathrooms': 0  
}

new2_df = pd.DataFrame([new_listing_parameters])

# Matching rest of the columns with training set
for col in X_train.columns:
    if col not in new2_df.columns:
        new2_df[col] = 0  # Addin missing columns
new2_df = new2_df[X_train.columns]  #reordering columns


predicted_price = rf.predict(new2_df)[0]
print(f"Predicted price for the new listing: ${predicted_price:.2f}")

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df[df['price'] < 500]['price'], bins=50, color='teal')
plt.title('Price Distribution Under 500', fontsize=14)
plt.xlabel('Price')
plt.ylabel('Listed properties')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='beds', y='price', data=df[df['price'] < 500], palette='Set2')

plt.title('Price vs Number of Beds')
plt.xlabel('Number of Beds')
plt.ylabel('Price')
plt.show()

# %%
property_cols = [col for col in df.columns if col.startswith("property_type_")]

properties = df[property_cols].sum().sort_values(ascending=False).head(10)

properties.plot(kind='barh', color='skyblue', figsize=(8,5))
plt.title('Top 10 Property Types Available')
plt.xlabel('Listed properties')
plt.gca().invert_yaxis()
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data=df[df['price'] < 200], x='review_scores_rating', y='price', alpha=0.3)

plt.title('Review Score vs Price Under 200 USD')
plt.xlabel('Review Score')

plt.ylabel('Price')
plt.show()

# %%
sns.scatterplot(x='price', y='host_experience_days', data=df[df['price'] < 500], alpha=0.3)
plt.title('Host Experience by Listing Price')

plt.ylabel('Host Experience in Days')

plt.xlabel('Price')
plt.show()

# %%
df['room_type'] = df[['room_type_Private room', 'room_type_Shared room']].apply(
    lambda x: 'Private room' if x[0] else ('Shared room' if x[1] else 'Entire home/apt'), axis=1)

sns.violinplot(x='room_type', y='price', data=df[df['price'] < 500], palette='pastel')

plt.title('Room Type vs. Price')

plt.xlabel('Room Type')
plt.ylabel('Price')

plt.show()
